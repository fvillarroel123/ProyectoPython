# %% [markdown]
# <h1>Proyecto Final</h1>
# <h3>Felipe Villarroel L.</h3>

# %%
### import requests

def indicadoresTodos():
    url = "https://mindicador.cl/api"
    
    res = requests.get(url)
    res = res.json()
    print(res)
    i = 0

    for llave, valor in res.items():
        if i > 2:
            print(valor["nombre"]+":",valor["valor"])
        i = i + 1

        
def tipoIndicador(tipoIndicador):
    url = "https://mindicador.cl/api/"
    #tipo = input("Ingrese tipo de indicador: ")
    
    res = requests.get("https://mindicador.cl/api/"+tipo)
    res = res.json()
    
    dicfyv = []
    
    print(res["nombre"])
    
    for llave, valor in res.items():
        if llave == "serie":
            i = 0
            for linea in valor:
                print("Fecha:", res["serie"][i]["fecha"][0:10], "Valor:", res["serie"][i]["valor"])
                dicfyv.append("Fecha:", res["serie"][i]["fecha"][0:10], "Valor:", res["serie"][i]["valor"])
                i = i + 1
                
    return dicfyv

def tipoIndFecha():
    url = "https://mindicador.cl/api/"
    tipo = input("Ingrese tipo de indicador: ")
    fecha = input("Ingrese fecha de la forma DD-MM-AAAA: ")
    
    res = requests.get("https://mindicador.cl/api/"+tipo+"/"+fecha)
    res = res.json()
    
    fech = res["serie"][0]["fecha"]
    
    print("Fecha:",fech[0:10], "Valor:", res["serie"][0]["valor"])
    
def tipoIndAnho():
    url = "https://mindicador.cl/api/"
    tipo = input("Ingrese tipo de indicador: ")
    anho = input("Ingrese año de la forma AAAA: ")

    res = requests.get("https://mindicador.cl/api/"+tipo+"/"+anho)
    res = res.json()

    for llave, valor in res.items():
        if llave == "serie":
            i = 0
            for linea in valor:
                print("Fecha:", res["serie"][i]["fecha"][0:10], "Valor:", res["serie"][i]["valor"])
                i = i + 1
                
                
def compValores():
    
    archivo = open("archivo.txt", "w")
    
    
    for valor in tipoIndicador("dolar"):
        archivo.write(valor)
    
    close(archivo)



#PROGRAMA:

print("CONSULTA DE INDICADORES ECONOMICOS DE CHILE")
respuesta = 10

while respuesta != 0:
    
    print("************************************")
    print("Escoja una opción para continuar:")
    print("1. Consultar todos los indicadores económicos")
    print("2. Consultar por tipo de indicador económico")
    print("3. Consultar por tipo de indicador económico dada una fecha determinada")
    print("4. Consultar por tipo de indicador económico dado un año determinado")
    print("0. Salir")
    respuesta = int(input())
    
    if respuesta == 1:
        print("Valor de todos los indicadores")
        print(indicadoresTodos())
    if respuesta == 2:        
        print("Consulta del valor del último mes de in indicador específico.")
        tipo = input("Ingrese tipo de indicador: ")
        print(tipoIndicador(tipo))
    if respuesta == 3:
        print(tipoIndFecha())
    if respuesta == 4:
        print(tipoIndAnho())
    if respuesta == 5:
        print(compValores())
    if respuesta == 0:
        print("Gracias por su tiempo, hasta pronto!")
        break
    else:
        print("Debe escoger un número de los indicados para continuar")
# Out:
# CONSULTA DE INDICADORES ECONOMICOS DE CHILE
# ************************************
# Escoja una opción para continuar:
# 1. Consultar todos los indicadores económicos
# 2. Consultar por tipo de indicador económico
# 3. Consultar por tipo de indicador económico dada una fecha determinada
# 4. Consultar por tipo de indicador económico dado un año determinado
# 0. Salir
# 2
# Consulta del valor del último mes de in indicador específico.
# Ingrese tipo de indicador: uf
# Unidad de fomento (UF)
# Fecha: 2019-09-07 Valor: 28005.72
# Fecha: 2019-09-06 Valor: 28003.91
# Fecha: 2019-09-05 Valor: 28002.11
# Fecha: 2019-09-04 Valor: 28000.3
# Fecha: 2019-09-03 Valor: 27998.5
# Fecha: 2019-09-02 Valor: 27996.69
# Fecha: 2019-09-01 Valor: 27994.89
# Fecha: 2019-08-31 Valor: 27993.08
# Fecha: 2019-08-30 Valor: 27991.28
# Fecha: 2019-08-29 Valor: 27989.48
# Fecha: 2019-08-28 Valor: 27987.67
# Fecha: 2019-08-27 Valor: 27985.87
# Fecha: 2019-08-26 Valor: 27984.06
# Fecha: 2019-08-25 Valor: 27982.26
# Fecha: 2019-08-24 Valor: 27980.46
# Fecha: 2019-08-23 Valor: 27978.65
# Fecha: 2019-08-22 Valor: 27976.85
# Fecha: 2019-08-21 Valor: 27975.05
# Fecha: 2019-08-20 Valor: 27973.25
# Fecha: 2019-08-19 Valor: 27971.44
# Fecha: 2019-08-18 Valor: 27969.64
# Fecha: 2019-08-17 Valor: 27967.84
# Fecha: 2019-08-16 Valor: 27966.03
# Fecha: 2019-08-15 Valor: 27964.23
# Fecha: 2019-08-14 Valor: 27962.43
# Fecha: 2019-08-13 Valor: 27960.63
# Fecha: 2019-08-12 Valor: 27958.83
# Fecha: 2019-08-11 Valor: 27957.02
# Fecha: 2019-08-10 Valor: 27955.22
# Fecha: 2019-08-09 Valor: 27953.42
# Fecha: 2019-08-08 Valor: 27953.42
# None
# Debe escoger un número de los indicados para continuar
# ************************************
# Escoja una opción para continuar:
# 1. Consultar todos los indicadores económicos
# 2. Consultar por tipo de indicador económico
# 3. Consultar por tipo de indicador económico dada una fecha determinada
# 4. Consultar por tipo de indicador económico dado un año determinado
# 0. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documentos/ProyectoFinal/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~/Documentos/ProyectoFinal/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/Documentos/ProyectoFinal/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/Documentos/ProyectoFinal/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-7b84dcabb76d> in <module>
#      72     print("4. Consultar por tipo de indicador económico dado un año determinado")
#      73     print("0. Salir")
# ---> 74     respuesta = int(input())
#      75
#      76     if respuesta == 1:
#
# ~/Documentos/ProyectoFinal/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# ~/Documentos/ProyectoFinal/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:
