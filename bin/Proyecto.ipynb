# %%
import requests
#import matplotlib.pyplot as plt

def monedasTodas():
    url = "https://api.gael.cl/general/public/monedas"
    
    res = requests.get(url)
    res = res.json()

    archivo = open("Monedas.txt", "w")
    
    for elemento in res:
        #print(elemento)
        archivo.write(str(elemento)+"\n")
        print("Código:", elemento["Codigo"])
        print("- Nombre:", elemento["Nombre"])
        print("- Valor:", elemento["Valor"])
        
    archivo.close()

    
def monedaEspecifica():
    print("Escriba uno de los siguientes códigos para consultar")
    url2 = "https://api.gael.cl/general/public/monedas/"
    url1 = "https://api.gael.cl/general/public/monedas"
    
    res1 = requests.get(url1)
    res1 = res1.json()
    for elemento in res1:
        print("Código:", elemento["Codigo"], elemento["Nombre"])
    
    tipo = input("Escriba Código: ")
    
    res2 = requests.get(url2+tipo.upper())
    res2 = res2.json()
    
    for llave, valor in res2.items():
        print(llave+":", valor)

    
        
def clima():
    url = "https://api.gael.cl/general/public/clima"
    
    res = requests.get(url)
    res = res.json()
    
    archivo = open("Estaciones Climaticas.txt", "w")
    
    sumTemp = 0
    sumHum = 0
    i = 0
    
    for elemento in res:
        #print(elemento)
        archivo.write(str(elemento)+"\n")
        print("Código:", elemento["Codigo"])
        print("- Estación:", elemento["Estacion"])
        print("- Hora Actualización:", elemento["HoraUpdate"])
        print("- Temperatura:", elemento["Temp"])
        print("- Humedad:", elemento["Humedad"])
        print("- Estado:", elemento["Estado"])
        sumTemp = sumTemp + float(elemento["Temp"])
        sumHum = sumHum + float(elemento["Humedad"])
        i = i + 1
        
    archivo.close()
    promTemp = sumTemp/i
    promHum = sumHum/i
    
    print("La temperatura promedio es de", promTemp, "grados.")
    print("La humedad promedio es del", promHum, "%.")
    


    
def climaEspecifico():
    url2 = "https://api.gael.cl/general/public/clima/"
    url1 = "https://api.gael.cl/general/public/clima"
    print("Escriba uno de los siguientes códigos para consultar")
    res1 = requests.get(url1)
    res1 = res1.json()
    for elemento in res1:
        print("Código:", elemento["Codigo"], elemento["Estacion"])
    
    tipo = input("Escriba Código: ")
    res2 = requests.get(url2+tipo.upper())
    res2 = res2.json()
    
    for llave, valor in res2.items():
        print(llave+":", valor)

def sismos():
    url = "https://api.gael.cl/general/public/sismos"
    
    res = requests.get(url)
    res = res.json()

    archivo = open("Sismos.txt", "w")
    
    sumMag = 0
    i = 0
    
    for elemento in res:
        archivo.write(str(elemento)+"\n")
        print("Fecha:", elemento["Fecha"])
        print("- Latitud:", elemento["Latitud"])
        print("- Longitud:", elemento["Longitud"])
        print("- Profundidad:", elemento["Profundidad"])
        print("- Magnitud:", elemento["Magnitud"])
        print("- Agencia", elemento["Agencia"])
        print("- Referencia Geográfica:", elemento["RefGeografica"])
        print("- Fecha Actualización:", elemento["FechaUpdate"])
        sumMag = sumMag + float(elemento["Magnitud"][0:2])
        
        i = i + 1
        
        
    archivo.close()
    prom = sumMag/i
    print("CONCLUSIÓN: El promedio de las magnitudes de los últimos", i, "sismos es de", prom)
    
def sismosPorFecha():
    url = "https://api.gael.cl/general/public/sismos"
    fecha = input("Ingrese fecha de la forma AAAA/MM/DD. Considerar fecha entre ayer y hoy.")
    
    res = requests.get(url)
    res = res.json()
    i = 0
    
    for elemento in res:
        if elemento["Fecha"][0:10] == fecha:
            print("Fecha:", elemento["Fecha"])
            print("- Latitud:", elemento["Latitud"])
            print("- Longitud:", elemento["Longitud"])
            print("- Profundidad:", elemento["Profundidad"])
            print("- Magnitud:", elemento["Magnitud"])
            print("- Agencia:", elemento["Agencia"])
            print("- Referencia Geográfica:", elemento["RefGeografica"])
            print("- Fecha Actualización:", elemento["FechaUpdate"])
            i = i + 1
            
    if i == 0:
        print("No hay sismos registros de la fecha indicada")           
            
def graficos():
    url = "https://api.gael.cl/general/public/sismos"
    
    res = requests.get(url)
    res = res.json()
    listaSismos = []
    
    for elemento in res:
        listaSismos.append(elemento)
        
    fig = plt.figure(figsize=(20,10))
    ax = fig.add_subplot(111)
    plt.plot(listaSismos["Fecha"], listaSismos["Magnitud"])
    plt.ylabel("Temperatura")
    plt.xlabel("Ciudades")
    ax.set_xticklabels(listaSismos["Fecha"], rotation=45 )
    plt.show()

#PROGRAMA:

print("CONSULTA DE INDICADORES ECONOMICOS DE CHILE")
respuesta = 10

while respuesta != 0:
    
    print("************************************")
    print("Escoja una opción para continuar:")
    print("1. Consultar todos los indicadores económicos")
    print("2. Consulta moneda específica")
    print("3. Estaciones Climáticas")
    print("4. Consulta por Estación específica")
    print("5. Últimos Sismos")
    print("6. Consulta Sismos por fecha")
    print("7. Gráfico de sismos")
    print("0. Salir")
    respuesta = int(input())
    
    if respuesta == 1:
        print("Valor de todos los indicadores")
        monedasTodas()
    elif respuesta == 2:        
        monedaEspecifica()
    elif respuesta == 3:
        clima()
    elif respuesta == 4:
        climaEspecifico()
    elif respuesta == 5:
        sismos()
    elif respuesta == 6:
        sismosPorFecha()
    #if respuesta == 7:
        #print(graficos())
    elif respuesta == 0:
        print("Gracias por su tiempo, hasta pronto!")
        break
    else:
        print("Debe escoger un número de los indicados para continuar")
# Out:
# CONSULTA DE INDICADORES ECONOMICOS DE CHILE
# ************************************
# Escoja una opción para continuar:
# 1. Consultar todos los indicadores económicos
# 2. Consulta moneda específica
# 3. Estaciones Climáticas
# 4. Consulta por Estación específica
# 5. Últimos Sismos
# 6. Consulta Sismos por fecha
# 7. Gráfico de sismos
# 0. Salir
# 1
# Valor de todos los indicadores
# Código: UF
# - Nombre: Unidad de Fomento
# - Valor: 28009,33
# Código: USD
# - Nombre: Dolar Americano
# - Valor: 711,22
# Código: UTM
# - Nombre: Unidad Tributaria Mensual
# - Valor: 49131,00
# Código: THB
# - Nombre: Baht tailandés
# - Valor: 23,21
# Código: PAB
# - Nombre: Balboa panameño
# - Valor: 711,22
# Código: VEF
# - Nombre: Bolívar fuerte venezolano
# - Valor: 0,03
# Código: BOB
# - Nombre: Boliviano
# - Valor: 103,68
# Código: CRC
# - Nombre: Colón costarricense
# - Valor: 1,23
# Código: CZK
# - Nombre: Corona Checa
# - Valor: 30,38
# Código: DKK
# - Nombre: Corona Danesa
# - Valor: 105,19
# Código: SKK
# - Nombre: Corona Eslovaca
# - Valor: 26,05
# Código: ISK
# - Nombre: Corona islandesa
# - Valor: 5,64
# Código: NOK
# - Nombre: Corona noruega
# - Valor: 79,30
# Código: SEK
# - Nombre: Corona sueca
# - Valor: 73,89
# Código: DEG
# - Nombre: DEG
# - Valor: 973,74
# Código: AED
# - Nombre: Dírham de Emiratos Árabes Unidos
# - Valor: 193,69
# Código: AUD
# - Nombre: Dólar australiano
# - Valor: 487,17
# Código: CAD
# - Nombre: Dólar canadiense
# - Valor: 540,24
# Código: BMD
# - Nombre: Dólar de bermudas
# - Valor: 711,22
# Código: KYD
# - Nombre: Dólar de Islas Caimán
# - Valor: 867,34
# Código: BSD
# - Nombre: Dólar de las Bahamas
# - Valor: 711,22
# Código: FJD
# - Nombre: Dolár fiyiano
# - Valor: 325,10
# Código: HKD
# - Nombre: Dólar hongkonés
# - Valor: 90,74
# Código: NZD
# - Nombre: Dólar neozelandés
# - Valor: 457,52
# Código: SGD
# - Nombre: Dólar singapurense
# - Valor: 515,15
# Código: TWD
# - Nombre: Dólar taiwanés
# - Valor: 22,78
# Código: EUR
# - Nombre: Euro
# - Valor: 784,75
# Código: HUF
# - Nombre: Forint húngaro
# - Valor: 2,38
# Código: XPF
# - Nombre: Franco de la Polinesia Francesa
# - Valor: 6,60
# Código: CHF
# - Nombre: Franco suizo
# - Valor: 720,37
# Código: PYG
# - Nombre: Guaraní  paraguayo
# - Valor: 0,11
# Código: UAH
# - Nombre: Hryvnia ucraniano
# - Valor: 28,40
# Código: RON
# - Nombre: Leu rumano
# - Valor: 165,97
# Código: EGP
# - Nombre: Libra egipcia
# - Valor: 43,25
# Código: GBP
# - Nombre: Libra esterlina
# - Valor: 874,27
# Código: TRY
# - Nombre: Nueva lira turca
# - Valor: 124,43
# Código: PEN
# - Nombre: Nuevo sol peruano
# - Valor: 212,94
# Código: ARS
# - Nombre: Peso argentino
# - Valor: 12,75
# Código: COP
# - Nombre: Peso colombiano
# - Valor: 0,21
# Código: CUP
# - Nombre: Peso cubano
# - Valor: 711,22
# Código: DOP
# - Nombre: Peso de República Dominicana
# - Valor: 13,69
# Código: PHP
# - Nombre: Peso filipino
# - Valor: 13,71
# Código: MXN
# - Nombre: Peso mexicano
# - Valor: 36,39
# Código: UYU
# - Nombre: Peso uruguayo
# - Valor: 19,55
# Código: GTQ
# - Nombre: Quetzal guatemalteco
# - Valor: 92,54
# Código: ZAR
# - Nombre: Rand sudafricano
# - Valor: 48,13
# Código: BRL
# - Nombre: Real brasileño
# - Valor: 174,75
# Código: IRR
# - Nombre: Rial iraní
# - Valor: 0,02
# Código: SAR
# - Nombre: Rial saudita
# - Valor: 189,66
# Código: MYR
# - Nombre: Ringgit malasio
# - Valor: 170,23
# Código: RUB
# - Nombre: Rublo ruso
# - Valor: 10,82
# Código: IDR
# - Nombre: Rupia de Indonesia
# - Valor: 0,05
# Código: INR
# - Nombre: Rupia india
# - Valor: 9,92
# Código: PKR
# - Nombre: Rupia pakistaní
# - Valor: 4,54
# Código: ILS
# - Nombre: Shekel israelí
# - Valor: 201,94
# Código: KZT
# - Nombre: Tenge de Kazajstán
# - Valor: 1,83
# Código: KRW
# - Nombre: Won coreano
# - Valor: 0,59
# Código: JPY
# - Nombre: Yen
# - Valor: 6,66
# Código: CNY
# - Nombre: Yuan
# - Valor: 100,18
# Código: PLN
# - Nombre: Zloty polaco
# - Valor: 180,81
# ************************************
# Escoja una opción para continuar:
# 1. Consultar todos los indicadores económicos
# 2. Consulta moneda específica
# 3. Estaciones Climáticas
# 4. Consulta por Estación específica
# 5. Últimos Sismos
# 6. Consulta Sismos por fecha
# 7. Gráfico de sismos
# 0. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~/.local/lib/python3.5/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/.local/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/.local/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e98c0ccd0949> in <module>
#     179     print("7. Gráfico de sismos")
#     180     print("0. Salir")
# --> 181     respuesta = int(input())
#     182
#     183     if respuesta == 1:
#
# ~/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# ~/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:
